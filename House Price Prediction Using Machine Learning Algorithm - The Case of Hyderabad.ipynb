# %% [markdown]
# Importing Libraries

# %%
import numpy as np # used for  numerical computations on data
import pandas as pd # converts data into dataframe 
import matplotlib.pyplot as plt #used to visualize 
import seaborn as sns

# %%
#Reading data and storing in data variable 
data = pd.read_csv('hyd_v2.csv')

# %%
data.head()
# Out:
#    active                                          amenities balconies  \
# 0    True  {"LIFT":true,"GYM":false,"INTERNET":false,"AC"...         3
# 1    True  {"LIFT":false,"GYM":false,"INTERNET":false,"AC...         1
# 2    True  {"LIFT":true,"GYM":true,"INTERNET":false,"AC":...         3
# 3    True  {"LIFT":false,"GYM":false,"INTERNET":false,"AC...         1
# 4    True  {"LIFT":true,"GYM":false,"INTERNET":false,"AC"...         2
#
#    bathroom  combineDescription  \
# 0         3                 NaN
# 1         2                 NaN
# 2         3                 NaN
# 3         2                 NaN
# 4         2                 NaN
#
#                                   completeStreetName  deposit facing  \
# 0  Shreya carnation, Block I, NCB Enclave, Gachib...    90000      W
# 1     Inner Ring Rd,  near RTO Bandlaguda South Zone    45000      E
# 2  Rd Number 2, Shirdi Sai Nagar, Manikonda, Hyde...    80000      E
# 3  Plot No. 44, Road No. 1/A, kakatiya colony, LB...    18000      W
# 4  Madhapur HUDA Techno Enclave,  Near MaxCure Su...    80000      E
#
#   facingDesc  floor  ... property_size  reactivationSource rent_amount  \
# 0       West      3  ...          2200      USER_DASHBOARD       28000
# 1       East      2  ...          1200      USER_DASHBOARD       15000
# 2       East      0  ...          1800         MISSED_CALL       16000
# 3       West      2  ...           750         MISSED_CALL        9000
# 4       East      2  ...          1250                None       32500
#
#    sharedAccomodation                 shortUrl  swimmingPool totalFloor  \
# 0               False  http://nobr.kr/sv/9Kvqj         False          5
# 1               False  http://nobr.kr/sv/j2pD6         False          2
# 2               False  http://nobr.kr/sv/TXJmj         False          3
# 3               False  http://nobr.kr/sv/FnCsf         False          2
# 4               False  http://nobr.kr/sv/BQFRb         False          5
#
#   type_bhk waterSupply weight
# 0     BHK3   CORP_BORE    NaN
# 1     BHK3    BOREWELL    NaN
# 2     BHK3   CORP_BORE    NaN
# 3     BHK2   CORP_BORE    NaN
# 4     BHK2   CORP_BORE    NaN
#
# [5 rows x 36 columns]

# %%
data.tail()
# Out:
#        active                                          amenities balconies  \
# 19105    True  {"LIFT":true,"GYM":false,"INTERNET":false,"AC"...      None
# 19106    True  {"LIFT":false,"GYM":false,"INTERNET":false,"AC...         2
# 19107    True  {"LIFT":false,"GYM":false,"INTERNET":false,"AC...      None
# 19108    True  {"LIFT":false,"GYM":false,"INTERNET":false,"AC...      None
# 19109    True  {"LIFT":false,"GYM":false,"INTERNET":false,"AC...      None
#
#        bathroom  combineDescription  \
# 19105         1                 NaN
# 19106         2                 NaN
# 19107         3                 NaN
# 19108         1                 NaN
# 19109         1                 NaN
#
#                                       completeStreetName  deposit facing  \
# 19105   Dargah Road LIG Chitrapuri Colony,  Nagar nea...    17000   None
# 19106         East Gayathri Nagar Near More Super Market     8500      S
# 19107          Pragathi Nagar near Vasundhara Hospital      30000   None
# 19108                   Road no 2 ,Near Ramalayam Temple    13000   None
# 19109              ce colony near Sri Srinivasa Hospital    11000   None
#
#       facingDesc  floor  ... property_size  reactivationSource rent_amount  \
# 19105        NaN      0  ...           500                None        8500
# 19106      South      2  ...           900                None        8500
# 19107        NaN      3  ...          1150  PROPERTY_DASHBOARD       15000
# 19108        NaN      3  ...           500  PROPERTY_DASHBOARD        7000
# 19109        NaN      1  ...           400  PROPERTY_DASHBOARD        5500
#
#        sharedAccomodation                 shortUrl  swimmingPool totalFloor  \
# 19105               False  http://nobr.kr/sv/LYsBc         False          5
# 19106               False  http://nobr.kr/sv/45R5g         False          4
# 19107               False  http://nobr.kr/sv/B2R5g         False          3
# 19108               False  http://nobr.kr/sv/PyQ5g         False          3
# 19109               False  http://nobr.kr/sv/JZWBb         False          1
#
#       type_bhk waterSupply weight
# 19105     BHK1        None    NaN
# 19106     BHK2    BOREWELL    NaN
# 19107     BHK2        None    NaN
# 19108     BHK1        None    NaN
# 19109     BHK1        None    NaN
#
# [5 rows x 36 columns]

# %%
x = data.isnull().sum()
x
# Out:
# active                    0
# amenities                 0
# balconies                 0
# bathroom                  0
# combineDescription    19110
# completeStreetName        2
# deposit                   0
# facing                    0
# facingDesc             9541
# floor                     0
# furnishingDesc            0
# gym                       0
# id                        0
# isMaintenance             0
# lift                      0
# loanAvailable             0
# locality                  6
# localityId                0
# location                  0
# maintenanceAmount         0
# ownerName                 0
# parking                   0
# parkingDesc               0
# propertyTitle             0
# propertyType              0
# property_age              0
# property_size             0
# reactivationSource       63
# rent_amount               0
# sharedAccomodation        0
# shortUrl                  0
# swimmingPool              0
# totalFloor                0
# type_bhk                  0
# waterSupply               0
# weight                19110
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19110 entries, 0 to 19109
# Data columns (total 36 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   active              19110 non-null  bool
#  1   amenities           19110 non-null  object
#  2   balconies           19110 non-null  object
#  3   bathroom            19110 non-null  int64
#  4   combineDescription  0 non-null      float64
#  5   completeStreetName  19108 non-null  object
#  6   deposit             19110 non-null  int64
#  7   facing              19110 non-null  object
#  8   facingDesc          9569 non-null   object
#  9   floor               19110 non-null  int64
#  10  furnishingDesc      19110 non-null  object
#  11  gym                 19110 non-null  bool
#  12  id                  19110 non-null  object
#  13  isMaintenance       19110 non-null  bool
#  14  lift                19110 non-null  bool
#  15  loanAvailable       19110 non-null  bool
#  16  locality            19104 non-null  object
#  17  localityId          19110 non-null  object
#  18  location            19110 non-null  object
#  19  maintenanceAmount   19110 non-null  object
#  20  ownerName           19110 non-null  object
#  21  parking             19110 non-null  object
#  22  parkingDesc         19110 non-null  object
#  23  propertyTitle       19110 non-null  object
#  24  propertyType        19110 non-null  object
#  25  property_age        19110 non-null  int64
#  26  property_size       19110 non-null  int64
#  27  reactivationSource  19047 non-null  object
#  28  rent_amount         19110 non-null  int64
#  29  sharedAccomodation  19110 non-null  bool
#  30  shortUrl            19110 non-null  object
#  31  swimmingPool        19110 non-null  bool
#  32  totalFloor          19110 non-null  int64
#  33  type_bhk            19110 non-null  object
#  34  waterSupply         19110 non-null  object
#  35  weight              0 non-null      float64
# dtypes: bool(7), float64(2), int64(7), object(20)
# memory usage: 4.4+ MB

# %%
data.describe()
# Out:
#            bathroom  combineDescription       deposit         floor  \
# count  19110.000000                 0.0  1.911000e+04  19110.000000
# mean       1.911826                 NaN  3.337933e+04      2.109158
# std        0.764841                 NaN  4.101519e+04      2.424864
# min        1.000000                 NaN  1.000000e+00      0.000000
# 25%        1.000000                 NaN  1.600000e+04      1.000000
# 50%        2.000000                 NaN  2.500000e+04      2.000000
# 75%        2.000000                 NaN  4.000000e+04      3.000000
# max       14.000000                 NaN  2.000000e+06     31.000000
#
#        property_age  property_size    rent_amount    totalFloor  weight
# count  19110.000000   19110.000000   19110.000000  19110.000000     0.0
# mean       3.782261    1067.674411   14919.719362      3.907902     NaN
# std        3.461540     549.019152    9623.547307      3.899450     NaN
# min       -1.000000       0.000000       0.000000      0.000000     NaN
# 25%        1.000000     700.000000    8999.000000      2.000000     NaN
# 50%        3.000000    1000.000000   12500.000000      3.000000     NaN
# 75%        5.000000    1334.000000   18000.000000      5.000000     NaN
# max       15.000000   12000.000000  100000.000000     80.000000     NaN

# %% [markdown]
# We have too many features that do not contribute to our model
# removing the irrelevant/unneccesary features from dataset

# %%
data.columns
# Out:
# Index(['active', 'amenities', 'balconies', 'bathroom', 'combineDescription',
#        'completeStreetName', 'deposit', 'facing', 'facingDesc', 'floor',
#        'furnishingDesc', 'gym', 'id', 'isMaintenance', 'lift', 'loanAvailable',
#        'locality', 'localityId', 'location', 'maintenanceAmount', 'ownerName',
#        'parking', 'parkingDesc', 'propertyTitle', 'propertyType',
#        'property_age', 'property_size', 'reactivationSource', 'rent_amount',
#        'sharedAccomodation', 'shortUrl', 'swimmingPool', 'totalFloor',
#        'type_bhk', 'waterSupply', 'weight'],
#       dtype='object')

# %%
New_Data = data.drop(['active', 'amenities', 'balconies', 
       'completeStreetName', 'facing', 'facingDesc',
        'id', 'isMaintenance', 'lift', 'loanAvailable',
         'ownerName',
       'reactivationSource', 
        'shortUrl', 'swimmingPool', 
        'weight','combineDescription',
                      'location',
],axis=1)

# %%
# after removing irrelevant columns 
New_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19110 entries, 0 to 19109
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bathroom            19110 non-null  int64
#  1   deposit             19110 non-null  int64
#  2   floor               19110 non-null  int64
#  3   furnishingDesc      19110 non-null  object
#  4   gym                 19110 non-null  bool
#  5   locality            19104 non-null  object
#  6   localityId          19110 non-null  object
#  7   maintenanceAmount   19110 non-null  object
#  8   parking             19110 non-null  object
#  9   parkingDesc         19110 non-null  object
#  10  propertyTitle       19110 non-null  object
#  11  propertyType        19110 non-null  object
#  12  property_age        19110 non-null  int64
#  13  property_size       19110 non-null  int64
#  14  rent_amount         19110 non-null  int64
#  15  sharedAccomodation  19110 non-null  bool
#  16  totalFloor          19110 non-null  int64
#  17  type_bhk            19110 non-null  object
#  18  waterSupply         19110 non-null  object
# dtypes: bool(2), int64(7), object(10)
# memory usage: 2.5+ MB

# %%
New_Data.describe()
# Out:
#            bathroom       deposit         floor  property_age  property_size  \
# count  19110.000000  1.911000e+04  19110.000000  19110.000000   19110.000000
# mean       1.911826  3.337933e+04      2.109158      3.782261    1067.674411
# std        0.764841  4.101519e+04      2.424864      3.461540     549.019152
# min        1.000000  1.000000e+00      0.000000     -1.000000       0.000000
# 25%        1.000000  1.600000e+04      1.000000      1.000000     700.000000
# 50%        2.000000  2.500000e+04      2.000000      3.000000    1000.000000
# 75%        2.000000  4.000000e+04      3.000000      5.000000    1334.000000
# max       14.000000  2.000000e+06     31.000000     15.000000   12000.000000
#
#          rent_amount    totalFloor
# count   19110.000000  19110.000000
# mean    14919.719362      3.907902
# std      9623.547307      3.899450
# min         0.000000      0.000000
# 25%      8999.000000      2.000000
# 50%     12500.000000      3.000000
# 75%     18000.000000      5.000000
# max    100000.000000     80.000000

# %%
#Checking if our dataset/variable's if they contain any missing value or not 
New_Data.isnull().sum()
# Out:
# bathroom              0
# deposit               0
# floor                 0
# furnishingDesc        0
# gym                   0
# locality              6
# localityId            0
# maintenanceAmount     0
# parking               0
# parkingDesc           0
# propertyTitle         0
# propertyType          0
# property_age          0
# property_size         0
# rent_amount           0
# sharedAccomodation    0
# totalFloor            0
# type_bhk              0
# waterSupply           0
# dtype: int64

# %% [markdown]
# Encoding Data
# Linear regression model works only with numerical data

# %%
New_Data.replace({'parking':{'BOTH':0,'TWO_WHEELER':1,'FOUR_WHEELER':2,'NONE':3}},inplace=True)
New_Data.replace({'type_bhk':{'RK1':0.5,'BHK1':1,'BHK2':2,'BHK3':3,'BHK4':4,'BHK4PLUS':5}},inplace=True)
New_Data.replace({'maintenanceAmount':{'None':int(0)}},inplace=True)
New_Data.replace({'furnishingDesc':{'Unfurnished':0,'Semi':1,'Full':2}},inplace=True)

# %%
New_Data['gym'] = New_Data['gym'].astype(int)

# %%
New_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19110 entries, 0 to 19109
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bathroom            19110 non-null  int64
#  1   deposit             19110 non-null  int64
#  2   floor               19110 non-null  int64
#  3   furnishingDesc      19110 non-null  int64
#  4   gym                 19110 non-null  int32
#  5   locality            19104 non-null  object
#  6   localityId          19110 non-null  object
#  7   location            19110 non-null  object
#  8   maintenanceAmount   19110 non-null  object
#  9   parking             19110 non-null  int64
#  10  parkingDesc         19110 non-null  object
#  11  propertyTitle       19110 non-null  object
#  12  propertyType        19110 non-null  object
#  13  property_age        19110 non-null  int64
#  14  property_size       19110 non-null  int64
#  15  rent_amount         19110 non-null  int64
#  16  sharedAccomodation  19110 non-null  bool
#  17  totalFloor          19110 non-null  int64
#  18  type_bhk            19110 non-null  float64
#  19  waterSupply         19110 non-null  object
# dtypes: bool(1), float64(1), int32(1), int64(9), object(8)
# memory usage: 2.7+ MB

# %%
#Checking Correlations between variables
sns.heatmap(New_Data.corr(), annot = True)
plt.rcParams['figure.figsize'] = (20,7)
plt.show()
# Out:
# C:\Users\MohdS\AppData\Local\Temp\ipykernel_10012\2890091608.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(New_Data.corr(), annot = True)

# %%
New_Data['gym'].unique()
# Out:
# array([0, 1])

# %%
print(New_Data[['localityId']])
# Out:
#                       localityId
# 0           gachibowli_hyderabad
# 1      chandrayangutta_hyderabad
# 2            manikonda_hyderabad
# 3                      NOT_FOUND
# 4          hitech_city_hyderabad
# ...                          ...
# 19105         rai_durg_hyderabad
# 19106                  NOT_FOUND
# 19107         moosapet_hyderabad
# 19108                  NOT_FOUND
# 19109    santosh_nagar_hyderabad
#
# [19110 rows x 1 columns]
